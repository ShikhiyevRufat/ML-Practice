# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.read_excel('flight_price.xlsx')
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
df[df['Price'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Airline, Date_of_Journey, Source, Destination, Route, Dep_Time, Arrival_Time, Duration, Total_Stops, Additional_Info, Price]
# Index: []

# %%
df['Ticket_Price'] = '$' + df['Price'].astype(str) 
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
df['Date_of_Journey'].unique()
# Out:
# array(['24/03/2019', '1/05/2019', '9/06/2019', '12/05/2019', '01/03/2019',
#        '24/06/2019', '12/03/2019', '27/05/2019', '1/06/2019',
#        '18/04/2019', '9/05/2019', '24/04/2019', '3/03/2019', '15/04/2019',
#        '12/06/2019', '6/03/2019', '21/03/2019', '3/04/2019', '6/05/2019',
#        '15/05/2019', '18/06/2019', '15/06/2019', '6/04/2019',
#        '18/05/2019', '27/06/2019', '21/05/2019', '06/03/2019',
#        '3/06/2019', '15/03/2019', '3/05/2019', '9/03/2019', '6/06/2019',
#        '24/05/2019', '09/03/2019', '1/04/2019', '21/04/2019',
#        '21/06/2019', '27/03/2019', '18/03/2019', '12/04/2019',
#        '9/04/2019', '1/03/2019', '03/03/2019', '27/04/2019'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# Ticket_Price       0
# dtype: int64

# %%
df['Date_of_Journey'] = pd.to_datetime(df['Date_of_Journey'], dayfirst=True)
df['Date_of_Journey'] = df['Date_of_Journey'].dt.strftime('%d %B %Y')

df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo   24 March 2019  Banglore   New Delhi
# 1        Air India     01 May 2019   Kolkata    Banglore
# 2      Jet Airways    09 June 2019     Delhi      Cochin
# 3           IndiGo     12 May 2019   Kolkata    Banglore
# 4           IndiGo   01 March 2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia   09 April 2019   Kolkata    Banglore
# 10679    Air India   27 April 2019   Kolkata    Banglore
# 10680  Jet Airways   27 April 2019  Banglore       Delhi
# 10681      Vistara   01 March 2019  Banglore   New Delhi
# 10682    Air India     09 May 2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
df['Arrival_Time'].unique()
# Out:
# array(['01:10 22 Mar', '13:15', '04:25 10 Jun', ..., '06:50 10 Mar',
#        '00:05 19 Mar', '21:20 13 Mar'], dtype=object)

# %%
df['Arrival_Time'] = df['Arrival_Time'].str.split(' ').str[0]

df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo   24 March 2019  Banglore   New Delhi
# 1        Air India     01 May 2019   Kolkata    Banglore
# 2      Jet Airways    09 June 2019     Delhi      Cochin
# 3           IndiGo     12 May 2019   Kolkata    Banglore
# 4           IndiGo   01 March 2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia   09 April 2019   Kolkata    Banglore
# 10679    Air India   27 April 2019   Kolkata    Banglore
# 10680  Jet Airways   27 April 2019  Banglore       Delhi
# 10681      Vistara   01 March 2019  Banglore   New Delhi
# 10682    Air India     09 May 2019     Delhi      Cochin
#
#                        Route Dep_Time Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20        01:10   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50        13:15   7h 25m     2 stops
# ...

# %%
df['Additional_Info'].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# Ticket_Price       0
# dtype: int64

# %%
df.drop('Route', axis = 1, inplace=True )

df
# Out:
#            Airline Date_of_Journey    Source Destination Dep_Time  \
# 0           IndiGo   24 March 2019  Banglore   New Delhi    22:20
# 1        Air India     01 May 2019   Kolkata    Banglore    05:50
# 2      Jet Airways    09 June 2019     Delhi      Cochin    09:25
# 3           IndiGo     12 May 2019   Kolkata    Banglore    18:05
# 4           IndiGo   01 March 2019  Banglore   New Delhi    16:50
# ...            ...             ...       ...         ...      ...
# 10678     Air Asia   09 April 2019   Kolkata    Banglore    19:55
# 10679    Air India   27 April 2019   Kolkata    Banglore    20:45
# 10680  Jet Airways   27 April 2019  Banglore       Delhi    08:20
# 10681      Vistara   01 March 2019  Banglore   New Delhi    11:30
# 10682    Air India     09 May 2019     Delhi      Cochin    10:55
#
#       Arrival_Time Duration Total_Stops Additional_Info  Price Ticket_Price
# 0            01:10   2h 50m    non-stop         No info   3897        $3897
# ...

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# Ticket_Price       0
# dtype: int64

# %%
df['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
df['Total_Stops'] = df['Total_Stops'].map({'non-stop':0, '2 stops':2, '1 stop':1, '3 stops':3, '4 stops':4, np.nan:5})

# %%
df[df['Total_Stops'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Airline, Date_of_Journey, Source, Destination, Dep_Time, Arrival_Time, Duration, Total_Stops, Additional_Info, Price, Ticket_Price]
# Index: []

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# Ticket_Price       0
# dtype: int64

# %%
df.drop("Price", axis=1, inplace=True)

df
# Out:
#            Airline Date_of_Journey    Source Destination Dep_Time  \
# 0           IndiGo   24 March 2019  Banglore   New Delhi    22:20
# 1        Air India     01 May 2019   Kolkata    Banglore    05:50
# 2      Jet Airways    09 June 2019     Delhi      Cochin    09:25
# 3           IndiGo     12 May 2019   Kolkata    Banglore    18:05
# 4           IndiGo   01 March 2019  Banglore   New Delhi    16:50
# ...            ...             ...       ...         ...      ...
# 10678     Air Asia   09 April 2019   Kolkata    Banglore    19:55
# 10679    Air India   27 April 2019   Kolkata    Banglore    20:45
# 10680  Jet Airways   27 April 2019  Banglore       Delhi    08:20
# 10681      Vistara   01 March 2019  Banglore   New Delhi    11:30
# 10682    Air India     09 May 2019     Delhi      Cochin    10:55
#
#       Arrival_Time Duration  Total_Stops Additional_Info Ticket_Price
# 0            01:10   2h 50m            0         No info        $3897
# ...

# %%
df['Total_Stops'].unique()
# Out:
# array([0, 2, 1, 3, 5, 4], dtype=int64)

# %%
df.to_excel("clean_data.xlsx", sheet_name='Sheet1', index=False)
